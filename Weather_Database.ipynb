# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# %%
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
coordinates = list (lat_lng)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 744

# %%
# API key
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f8d7ed020ef7b067730ae11ad58fadc2

# %%
city_data = []

print('Begin Data Retrieval')
print('-' * 10)


record_count = 1
set_count = 1
for index, city in enumerate(cities):
    

    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        

    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        city_data.append(
        {
            'City': city,
            'Country': city_country,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Current Description': city_weather_description,
            
        })
    except:
        print('City not found. Skip')
        pass

print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Begin Data Retrieval
# ----------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | champerico
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | qandala
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | sumbawa
# City not found. Skip
# Processing Record 10 of Set 1 | pangnirtung
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | touros
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | pangai
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | husavik
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | northam
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | vao
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | bambari
# Processing Record 23 of Set 1 | luderitz
# Processing Record 24 of Set 1 | deputatskiy
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | enid
# Processing Record 27 of Set 1 | lagoa
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | fort nelson
# Processing Record 30 of Set 1 | srandakan
# Processing Record 31 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skip
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | chapais
# Processing Record 37 of Set 1 | saldanha
# Processing Record 38 of Set 1 | damghan
# Processing Record 39 of Set 1 | itoman
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | kysyl-syr
# Processing Record 42 of Set 1 | laje
# Processing Record 43 of Set 1 | ostersund
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | olga
# Processing Record 46 of Set 1 | trincomalee
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | itarema
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | lolua
# City not found. Skip
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | faanui
# Processing Record 5 of Set 2 | lata
# Processing Record 6 of Set 2 | wewak
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | belyy yar
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skip
# Processing Record 13 of Set 2 | kiruna
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | sao filipe
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | turayf
# Processing Record 20 of Set 2 | ahipara
# Processing Record 21 of Set 2 | atar
# Processing Record 22 of Set 2 | dingle
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skip
# Processing Record 24 of Set 2 | bengkulu
# Processing Record 25 of Set 2 | acajutla
# Processing Record 26 of Set 2 | nouadhibou
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | laguna
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skip
# Processing Record 31 of Set 2 | tsihombe
# City not found. Skip
# Processing Record 32 of Set 2 | saint-pierre
# Processing Record 33 of Set 2 | sharkan
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skip
# Processing Record 35 of Set 2 | tres lagoas
# Processing Record 36 of Set 2 | iqaluit
# Processing Record 37 of Set 2 | gravdal
# Processing Record 38 of Set 2 | sobolevo
# Processing Record 39 of Set 2 | amderma
# City not found. Skip
# Processing Record 40 of Set 2 | muzhi
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | ixtapa
# Processing Record 43 of Set 2 | constitucion
# Processing Record 44 of Set 2 | vostok
# Processing Record 45 of Set 2 | abonnema
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | jhawarian
# Processing Record 48 of Set 2 | port hedland
# Processing Record 49 of Set 2 | sturgeon bay
# Processing Record 50 of Set 2 | puerto narino
# Processing Record 1 of Set 3 | fukue
# Processing Record 2 of Set 3 | camapua
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | fairview
# Processing Record 5 of Set 3 | narsaq
# Processing Record 6 of Set 3 | the valley
# Processing Record 7 of Set 3 | nouakchott
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | aquiraz
# Processing Record 10 of Set 3 | sola
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | salta
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | marsh harbour
# Processing Record 17 of Set 3 | buluang
# Processing Record 18 of Set 3 | nishihara
# Processing Record 19 of Set 3 | olafsvik
# Processing Record 20 of Set 3 | muros
# Processing Record 21 of Set 3 | harper
# Processing Record 22 of Set 3 | talnakh
# Processing Record 23 of Set 3 | ambanja
# Processing Record 24 of Set 3 | araouane
# Processing Record 25 of Set 3 | jumla
# Processing Record 26 of Set 3 | kenora
# Processing Record 27 of Set 3 | kumba
# Processing Record 28 of Set 3 | ponta delgada
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | tautira
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | uwajima
# Processing Record 33 of Set 3 | tumannyy
# City not found. Skip
# Processing Record 34 of Set 3 | mattru
# Processing Record 35 of Set 3 | poole
# Processing Record 36 of Set 3 | mount gambier
# Processing Record 37 of Set 3 | dabat
# Processing Record 38 of Set 3 | semnan
# Processing Record 39 of Set 3 | hailar
# Processing Record 40 of Set 3 | adrar
# Processing Record 41 of Set 3 | wanning
# Processing Record 42 of Set 3 | batagay
# Processing Record 43 of Set 3 | angoche
# Processing Record 44 of Set 3 | takaka
# Processing Record 45 of Set 3 | san policarpo
# Processing Record 46 of Set 3 | qasigiannguit
# Processing Record 47 of Set 3 | anjozorobe
# Processing Record 48 of Set 3 | bardiyah
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | warqla
# City not found. Skip
# Processing Record 1 of Set 4 | wuwei
# Processing Record 2 of Set 4 | luena
# Processing Record 3 of Set 4 | teguise
# Processing Record 4 of Set 4 | hobyo
# Processing Record 5 of Set 4 | quelimane
# Processing Record 6 of Set 4 | gargzdai
# Processing Record 7 of Set 4 | chase
# Processing Record 8 of Set 4 | karaul
# City not found. Skip
# Processing Record 9 of Set 4 | chiavari
# Processing Record 10 of Set 4 | linjiang
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | nizhniy odes
# Processing Record 13 of Set 4 | shimoda
# Processing Record 14 of Set 4 | makakilo city
# Processing Record 15 of Set 4 | mahebourg
# Processing Record 16 of Set 4 | klaksvik
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | metro
# Processing Record 19 of Set 4 | piacabucu
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | beloha
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | alofi
# Processing Record 24 of Set 4 | asfi
# Processing Record 25 of Set 4 | okha
# Processing Record 26 of Set 4 | port alfred
# Processing Record 27 of Set 4 | tricase
# Processing Record 28 of Set 4 | illoqqortoormiut
# City not found. Skip
# Processing Record 29 of Set 4 | ginir
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | la ronge
# Processing Record 32 of Set 4 | samarai
# Processing Record 33 of Set 4 | fortuna
# Processing Record 34 of Set 4 | vestmannaeyjar
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | mathbaria
# Processing Record 38 of Set 4 | edd
# Processing Record 39 of Set 4 | yuancheng
# Processing Record 40 of Set 4 | hualmay
# Processing Record 41 of Set 4 | piracanjuba
# Processing Record 42 of Set 4 | jiangyou
# Processing Record 43 of Set 4 | aklavik
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skip
# Processing Record 46 of Set 4 | manzhouli
# Processing Record 47 of Set 4 | hvide sande
# Processing Record 48 of Set 4 | santa isabel do rio negro
# Processing Record 49 of Set 4 | butaritari
# Processing Record 50 of Set 4 | vidim
# Processing Record 1 of Set 5 | kon tum
# Processing Record 2 of Set 5 | khatanga
# Processing Record 3 of Set 5 | new norfolk
# Processing Record 4 of Set 5 | tezu
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | dapaong
# Processing Record 7 of Set 5 | tabora
# Processing Record 8 of Set 5 | faya
# Processing Record 9 of Set 5 | saint-francois
# Processing Record 10 of Set 5 | muriti
# Processing Record 11 of Set 5 | killarney
# Processing Record 12 of Set 5 | dossor
# Processing Record 13 of Set 5 | tanete
# Processing Record 14 of Set 5 | chuy
# Processing Record 15 of Set 5 | tuktoyaktuk
# Processing Record 16 of Set 5 | barbosa ferraz
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | tacuarembo
# Processing Record 19 of Set 5 | pevek
# Processing Record 20 of Set 5 | quatre cocos
# Processing Record 21 of Set 5 | verkh-usugli
# Processing Record 22 of Set 5 | liepaja
# Processing Record 23 of Set 5 | yara
# Processing Record 24 of Set 5 | sayyan
# Processing Record 25 of Set 5 | manokwari
# Processing Record 26 of Set 5 | camacha
# Processing Record 27 of Set 5 | ribeira grande
# Processing Record 28 of Set 5 | anadyr
# Processing Record 29 of Set 5 | sokoto
# Processing Record 30 of Set 5 | mao
# Processing Record 31 of Set 5 | saint-louis
# Processing Record 32 of Set 5 | jardim
# Processing Record 33 of Set 5 | riyadh
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | la huerta
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | tsiroanomandidy
# Processing Record 38 of Set 5 | buala
# Processing Record 39 of Set 5 | kharan
# Processing Record 40 of Set 5 | traralgon
# Processing Record 41 of Set 5 | comodoro rivadavia
# Processing Record 42 of Set 5 | emporia
# Processing Record 43 of Set 5 | longlac
# City not found. Skip
# Processing Record 44 of Set 5 | panzhihua
# Processing Record 45 of Set 5 | susanville
# Processing Record 46 of Set 5 | rio cuarto
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | east london
# Processing Record 49 of Set 5 | sioux lookout
# Processing Record 50 of Set 5 | namibe
# Processing Record 1 of Set 6 | talara
# Processing Record 2 of Set 6 | qabis
# City not found. Skip
# Processing Record 3 of Set 6 | lorengau
# Processing Record 4 of Set 6 | anahuac
# Processing Record 5 of Set 6 | ambilobe
# Processing Record 6 of Set 6 | poum
# Processing Record 7 of Set 6 | manapparai
# Processing Record 8 of Set 6 | chokurdakh
# Processing Record 9 of Set 6 | kodiak
# Processing Record 10 of Set 6 | yichang
# Processing Record 11 of Set 6 | axim
# Processing Record 12 of Set 6 | nevsehir
# Processing Record 13 of Set 6 | lavrentiya
# Processing Record 14 of Set 6 | areosa
# Processing Record 15 of Set 6 | casablanca
# Processing Record 16 of Set 6 | meulaboh
# Processing Record 17 of Set 6 | shirokiy
# Processing Record 18 of Set 6 | port blair
# Processing Record 19 of Set 6 | pauini
# Processing Record 20 of Set 6 | coquimbo
# Processing Record 21 of Set 6 | churapcha
# Processing Record 22 of Set 6 | ouro preto do oeste
# Processing Record 23 of Set 6 | maceio
# Processing Record 24 of Set 6 | ostrovnoy
# Processing Record 25 of Set 6 | vila velha
# Processing Record 26 of Set 6 | qui nhon
# Processing Record 27 of Set 6 | salalah
# Processing Record 28 of Set 6 | mackay
# Processing Record 29 of Set 6 | shache
# Processing Record 30 of Set 6 | saint anthony
# Processing Record 31 of Set 6 | kavaratti
# Processing Record 32 of Set 6 | skalistyy
# City not found. Skip
# Processing Record 33 of Set 6 | oga
# Processing Record 34 of Set 6 | katherine
# Processing Record 35 of Set 6 | vanavara
# Processing Record 36 of Set 6 | umzimvubu
# City not found. Skip
# Processing Record 37 of Set 6 | rio gallegos
# Processing Record 38 of Set 6 | norwich
# Processing Record 39 of Set 6 | pochutla
# Processing Record 40 of Set 6 | nagorsk
# Processing Record 41 of Set 6 | ndele
# Processing Record 42 of Set 6 | dingli
# Processing Record 43 of Set 6 | palimbang
# Processing Record 44 of Set 6 | dunedin
# Processing Record 45 of Set 6 | grindavik
# Processing Record 46 of Set 6 | xai-xai
# Processing Record 47 of Set 6 | ovsyanka
# Processing Record 48 of Set 6 | moundou
# Processing Record 49 of Set 6 | katsuura
# Processing Record 50 of Set 6 | beitbridge
# Processing Record 1 of Set 7 | ornskoldsvik
# Processing Record 2 of Set 7 | quthing
# Processing Record 3 of Set 7 | deniliquin
# Processing Record 4 of Set 7 | buchanan
# Processing Record 5 of Set 7 | saint george
# Processing Record 6 of Set 7 | coihaique
# Processing Record 7 of Set 7 | galesong
# Processing Record 8 of Set 7 | nogliki
# Processing Record 9 of Set 7 | kerteh
# City not found. Skip
# Processing Record 10 of Set 7 | yenagoa
# Processing Record 11 of Set 7 | wattegama
# Processing Record 12 of Set 7 | nurobod
# Processing Record 13 of Set 7 | fort saint john
# City not found. Skip
# Processing Record 14 of Set 7 | banda aceh
# Processing Record 15 of Set 7 | walvis bay
# Processing Record 16 of Set 7 | tibu
# Processing Record 17 of Set 7 | indianola
# Processing Record 18 of Set 7 | necochea
# Processing Record 19 of Set 7 | lubbock
# Processing Record 20 of Set 7 | mehamn
# Processing Record 21 of Set 7 | marystown
# Processing Record 22 of Set 7 | dzerzhinskoye
# Processing Record 23 of Set 7 | leningradskiy
# Processing Record 24 of Set 7 | tshikapa
# Processing Record 25 of Set 7 | byron bay
# Processing Record 26 of Set 7 | bolungarvik
# City not found. Skip
# Processing Record 27 of Set 7 | airai
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | koutiala
# Processing Record 30 of Set 7 | shelbyville
# Processing Record 31 of Set 7 | rylsk
# Processing Record 32 of Set 7 | taunggyi
# Processing Record 33 of Set 7 | cuajinicuilapa
# Processing Record 34 of Set 7 | kamenka
# Processing Record 35 of Set 7 | puerto ayacucho
# Processing Record 36 of Set 7 | fairbanks
# Processing Record 37 of Set 7 | kuito
# Processing Record 38 of Set 7 | san carlos de bariloche
# Processing Record 39 of Set 7 | jijiga
# Processing Record 40 of Set 7 | sao jose da coroa grande
# Processing Record 41 of Set 7 | yulara
# Processing Record 42 of Set 7 | najran
# Processing Record 43 of Set 7 | puri
# Processing Record 44 of Set 7 | taltal
# Processing Record 45 of Set 7 | mollendo
# Processing Record 46 of Set 7 | ilulissat
# Processing Record 47 of Set 7 | norman wells
# Processing Record 48 of Set 7 | thunder bay
# Processing Record 49 of Set 7 | port hardy
# Processing Record 50 of Set 7 | rondonopolis
# Processing Record 1 of Set 8 | lagos
# Processing Record 2 of Set 8 | mahates
# Processing Record 3 of Set 8 | amga
# Processing Record 4 of Set 8 | berlevag
# Processing Record 5 of Set 8 | vidalia
# Processing Record 6 of Set 8 | longyearbyen
# Processing Record 7 of Set 8 | margate
# Processing Record 8 of Set 8 | zhanatas
# City not found. Skip
# Processing Record 9 of Set 8 | cap malheureux
# Processing Record 10 of Set 8 | yerbogachen
# Processing Record 11 of Set 8 | ballina
# Processing Record 12 of Set 8 | ankpa
# Processing Record 13 of Set 8 | pontes e lacerda
# Processing Record 14 of Set 8 | kristiansund
# Processing Record 15 of Set 8 | dongying
# Processing Record 16 of Set 8 | freeport
# Processing Record 17 of Set 8 | port-gentil
# Processing Record 18 of Set 8 | ust-kamchatsk
# City not found. Skip
# Processing Record 19 of Set 8 | vaitupu
# City not found. Skip
# Processing Record 20 of Set 8 | morropon
# Processing Record 21 of Set 8 | east wenatchee bench
# Processing Record 22 of Set 8 | zhangjiakou
# Processing Record 23 of Set 8 | cayenne
# Processing Record 24 of Set 8 | gao
# Processing Record 25 of Set 8 | fantanele
# Processing Record 26 of Set 8 | lethem
# Processing Record 27 of Set 8 | tirano
# Processing Record 28 of Set 8 | college
# Processing Record 29 of Set 8 | jimo
# Processing Record 30 of Set 8 | tarut
# Processing Record 31 of Set 8 | bathsheba
# Processing Record 32 of Set 8 | usinsk
# Processing Record 33 of Set 8 | nampula
# Processing Record 34 of Set 8 | chabahar
# Processing Record 35 of Set 8 | kibala
# Processing Record 36 of Set 8 | plettenberg bay
# Processing Record 37 of Set 8 | nijar
# Processing Record 38 of Set 8 | tuggurt
# City not found. Skip
# Processing Record 39 of Set 8 | arraial do cabo
# Processing Record 40 of Set 8 | ewa beach
# Processing Record 41 of Set 8 | kahului
# Processing Record 42 of Set 8 | porosozero
# Processing Record 43 of Set 8 | kununurra
# Processing Record 44 of Set 8 | bayan
# Processing Record 45 of Set 8 | kieta
# Processing Record 46 of Set 8 | seminole
# Processing Record 47 of Set 8 | onguday
# Processing Record 48 of Set 8 | rocha
# Processing Record 49 of Set 8 | lucapa
# Processing Record 50 of Set 8 | agadez
# Processing Record 1 of Set 9 | souillac
# Processing Record 2 of Set 9 | moose factory
# Processing Record 3 of Set 9 | saleaula
# City not found. Skip
# Processing Record 4 of Set 9 | statesville
# Processing Record 5 of Set 9 | jatiroto
# Processing Record 6 of Set 9 | namatanai
# Processing Record 7 of Set 9 | rio grande
# Processing Record 8 of Set 9 | pullman
# Processing Record 9 of Set 9 | huasahuasi
# Processing Record 10 of Set 9 | sakakah
# Processing Record 11 of Set 9 | ballyshannon
# Processing Record 12 of Set 9 | uri
# Processing Record 13 of Set 9 | cochrane
# Processing Record 14 of Set 9 | copiapo
# Processing Record 15 of Set 9 | rawson
# Processing Record 16 of Set 9 | yumen
# Processing Record 17 of Set 9 | ilhabela
# Processing Record 18 of Set 9 | zandvoort
# Processing Record 19 of Set 9 | trat
# Processing Record 20 of Set 9 | gataivai
# Processing Record 21 of Set 9 | taburi
# City not found. Skip
# Processing Record 22 of Set 9 | samusu
# City not found. Skip
# Processing Record 23 of Set 9 | prince george
# Processing Record 24 of Set 9 | bandarbeyla
# Processing Record 25 of Set 9 | pacific grove
# Processing Record 26 of Set 9 | kizhinga
# Processing Record 27 of Set 9 | caarapo
# Processing Record 28 of Set 9 | sitka
# Processing Record 29 of Set 9 | baykit
# Processing Record 30 of Set 9 | banjar
# Processing Record 31 of Set 9 | lubao
# Processing Record 32 of Set 9 | weyburn
# Processing Record 33 of Set 9 | laguna de perlas
# Processing Record 34 of Set 9 | tabiauea
# City not found. Skip
# Processing Record 35 of Set 9 | vila franca do campo
# Processing Record 36 of Set 9 | pacifica
# Processing Record 37 of Set 9 | point pedro
# Processing Record 38 of Set 9 | notre-dame-du-lac
# Processing Record 39 of Set 9 | turukhansk
# Processing Record 40 of Set 9 | port lincoln
# Processing Record 41 of Set 9 | prince rupert
# Processing Record 42 of Set 9 | huarmey
# Processing Record 43 of Set 9 | ridgetown
# Processing Record 44 of Set 9 | ormara
# Processing Record 45 of Set 9 | moron
# Processing Record 46 of Set 9 | jacareacanga
# Processing Record 47 of Set 9 | ipira
# Processing Record 48 of Set 9 | nizhneyansk
# City not found. Skip
# Processing Record 49 of Set 9 | topolobampo
# Processing Record 50 of Set 9 | tessalit
# Processing Record 1 of Set 10 | jalu
# Processing Record 2 of Set 10 | naryan-mar
# Processing Record 3 of Set 10 | bayanday
# Processing Record 4 of Set 10 | caravelas
# Processing Record 5 of Set 10 | marcona
# City not found. Skip
# Processing Record 6 of Set 10 | longhua
# Processing Record 7 of Set 10 | litoral del san juan
# City not found. Skip
# Processing Record 8 of Set 10 | asau
# Processing Record 9 of Set 10 | hasaki
# Processing Record 10 of Set 10 | dakar
# Processing Record 11 of Set 10 | sao jose do belmonte
# Processing Record 12 of Set 10 | akdepe
# Processing Record 13 of Set 10 | port antonio
# Processing Record 14 of Set 10 | kruisfontein
# Processing Record 15 of Set 10 | flinders
# Processing Record 16 of Set 10 | machali
# Processing Record 17 of Set 10 | wau
# Processing Record 18 of Set 10 | sorvag
# City not found. Skip
# Processing Record 19 of Set 10 | haibowan
# City not found. Skip
# Processing Record 20 of Set 10 | xinzhi
# Processing Record 21 of Set 10 | batemans bay
# Processing Record 22 of Set 10 | champa
# Processing Record 23 of Set 10 | sterling
# Processing Record 24 of Set 10 | kosgi
# City not found. Skip
# Processing Record 25 of Set 10 | pombas
# Processing Record 26 of Set 10 | sabang
# Processing Record 27 of Set 10 | tura
# Processing Record 28 of Set 10 | tiarei
# Processing Record 29 of Set 10 | horta
# Processing Record 30 of Set 10 | kenai
# Processing Record 31 of Set 10 | winslow
# Processing Record 32 of Set 10 | tilichiki
# Processing Record 33 of Set 10 | valparaiso
# Processing Record 34 of Set 10 | launceston
# Processing Record 35 of Set 10 | penarroya-pueblonuevo
# Processing Record 36 of Set 10 | tyler
# Processing Record 37 of Set 10 | eureka
# Processing Record 38 of Set 10 | jiddah
# City not found. Skip
# Processing Record 39 of Set 10 | aykhal
# Processing Record 40 of Set 10 | ambon
# Processing Record 41 of Set 10 | richards bay
# Processing Record 42 of Set 10 | raymondville
# Processing Record 43 of Set 10 | tocopilla
# Processing Record 44 of Set 10 | krasnaya gora
# Processing Record 45 of Set 10 | winnemucca
# Processing Record 46 of Set 10 | westport
# Processing Record 47 of Set 10 | mount isa
# Processing Record 48 of Set 10 | vardo
# Processing Record 49 of Set 10 | curitiba
# Processing Record 50 of Set 10 | lasa
# Processing Record 1 of Set 11 | nova olimpia
# Processing Record 2 of Set 11 | manggar
# Processing Record 3 of Set 11 | aksu
# Processing Record 4 of Set 11 | pocatky
# Processing Record 5 of Set 11 | shanghai
# Processing Record 6 of Set 11 | maniitsoq
# Processing Record 7 of Set 11 | porto velho
# Processing Record 8 of Set 11 | lyngdal
# Processing Record 9 of Set 11 | goderich
# Processing Record 10 of Set 11 | sentyabrskiy
# City not found. Skip
# Processing Record 11 of Set 11 | juba
# Processing Record 12 of Set 11 | pasighat
# Processing Record 13 of Set 11 | aswan
# Processing Record 14 of Set 11 | dera din panah
# City not found. Skip
# Processing Record 15 of Set 11 | hambantota
# Processing Record 16 of Set 11 | varnamo
# Processing Record 17 of Set 11 | purmerend
# Processing Record 18 of Set 11 | sibanicu
# Processing Record 19 of Set 11 | milingimbi
# City not found. Skip
# Processing Record 20 of Set 11 | komsomolskiy
# Processing Record 21 of Set 11 | silver city
# Processing Record 22 of Set 11 | maryborough
# Processing Record 23 of Set 11 | flin flon
# Processing Record 24 of Set 11 | vastervik
# City not found. Skip
# Processing Record 25 of Set 11 | grand gaube
# Processing Record 26 of Set 11 | do gonbadan
# Processing Record 27 of Set 11 | merauke
# Processing Record 28 of Set 11 | hofn
# Processing Record 29 of Set 11 | ilovlya
# Processing Record 30 of Set 11 | mentok
# City not found. Skip
# Processing Record 31 of Set 11 | sogdiondon
# City not found. Skip
# Processing Record 32 of Set 11 | sundumbili
# Processing Record 33 of Set 11 | bantry
# Processing Record 34 of Set 11 | kamenskoye
# City not found. Skip
# Processing Record 35 of Set 11 | ituiutaba
# Processing Record 36 of Set 11 | katobu
# Processing Record 37 of Set 11 | erenhot
# Processing Record 38 of Set 11 | la palma
# Processing Record 39 of Set 11 | sorata
# Processing Record 40 of Set 11 | yatou
# Processing Record 41 of Set 11 | avera
# Processing Record 42 of Set 11 | nakusp
# Processing Record 43 of Set 11 | terrace
# Processing Record 44 of Set 11 | peniche
# Processing Record 45 of Set 11 | liminangcong
# City not found. Skip
# Processing Record 46 of Set 11 | marlborough
# Processing Record 47 of Set 11 | metes
# Processing Record 48 of Set 11 | ancud
# Processing Record 49 of Set 11 | kampong thum
# Processing Record 50 of Set 11 | road town
# Processing Record 1 of Set 12 | meyungs
# City not found. Skip
# Processing Record 2 of Set 12 | palmer
# Processing Record 3 of Set 12 | acari
# Processing Record 4 of Set 12 | cockburn town
# Processing Record 5 of Set 12 | awjilah
# Processing Record 6 of Set 12 | ambulu
# Processing Record 7 of Set 12 | yar-sale
# Processing Record 8 of Set 12 | kurilsk
# Processing Record 9 of Set 12 | gizo
# Processing Record 10 of Set 12 | takoradi
# Processing Record 11 of Set 12 | svetlaya
# Processing Record 12 of Set 12 | oriximina
# Processing Record 13 of Set 12 | forest grove
# Processing Record 14 of Set 12 | zharkent
# Processing Record 15 of Set 12 | sao gabriel da cachoeira
# Processing Record 16 of Set 12 | harer
# Processing Record 17 of Set 12 | bolivar
# Processing Record 18 of Set 12 | mayo
# Processing Record 19 of Set 12 | pisco
# Processing Record 20 of Set 12 | sorong
# Processing Record 21 of Set 12 | daru
# Processing Record 22 of Set 12 | teahupoo
# Processing Record 23 of Set 12 | svetlyy
# Processing Record 24 of Set 12 | rognan
# Processing Record 25 of Set 12 | pueblo nuevo
# Processing Record 26 of Set 12 | san-pedro
# Processing Record 27 of Set 12 | japura
# Processing Record 28 of Set 12 | santa maria
# Processing Record 29 of Set 12 | port macquarie
# Processing Record 30 of Set 12 | concepcion del oro
# Processing Record 31 of Set 12 | guarapari
# Processing Record 32 of Set 12 | te anau
# Processing Record 33 of Set 12 | sechura
# Processing Record 34 of Set 12 | haines junction
# Processing Record 35 of Set 12 | grand-lahou
# Processing Record 36 of Set 12 | nizhneudinsk
# Processing Record 37 of Set 12 | hailun
# Processing Record 38 of Set 12 | snasa
# Processing Record 39 of Set 12 | dondo
# Processing Record 40 of Set 12 | belaya gora
# Processing Record 41 of Set 12 | torata
# Processing Record 42 of Set 12 | goure
# Processing Record 43 of Set 12 | vriezenveen
# Processing Record 44 of Set 12 | vernon
# Processing Record 45 of Set 12 | mys shmidta
# City not found. Skip
# Processing Record 46 of Set 12 | labuhan
# Processing Record 47 of Set 12 | severobaykalsk
# Processing Record 48 of Set 12 | sistranda
# Processing Record 49 of Set 12 | rawah
# Processing Record 50 of Set 12 | saint-augustin
# Processing Record 1 of Set 13 | kushiro
# Processing Record 2 of Set 13 | babanusah
# City not found. Skip
# Processing Record 3 of Set 13 | zalantun
# Processing Record 4 of Set 13 | marzuq
# Processing Record 5 of Set 13 | cabra
# Processing Record 6 of Set 13 | valdosta
# Processing Record 7 of Set 13 | barbar
# City not found. Skip
# Processing Record 8 of Set 13 | srednekolymsk
# Processing Record 9 of Set 13 | palabuhanratu
# City not found. Skip
# Processing Record 10 of Set 13 | kyren
# Processing Record 11 of Set 13 | artyom
# Processing Record 12 of Set 13 | joshimath
# Processing Record 13 of Set 13 | dzhusaly
# City not found. Skip
# Processing Record 14 of Set 13 | havoysund
# Processing Record 15 of Set 13 | kawana waters
# City not found. Skip
# Processing Record 16 of Set 13 | high level
# Processing Record 17 of Set 13 | rochelle
# Processing Record 18 of Set 13 | savannah bight
# Processing Record 19 of Set 13 | xiaoweizhai
# Processing Record 20 of Set 13 | suhbaatar
# Processing Record 21 of Set 13 | tumpat
# Processing Record 22 of Set 13 | doctor pedro p. pena
# City not found. Skip
# Processing Record 23 of Set 13 | hashtrud
# Processing Record 24 of Set 13 | rosetta
# Processing Record 25 of Set 13 | krasnoselkup
# Processing Record 26 of Set 13 | saint-paul
# Processing Record 27 of Set 13 | aloleng
# Processing Record 28 of Set 13 | karamea
# City not found. Skip
# Processing Record 29 of Set 13 | mantua
# Processing Record 30 of Set 13 | calbuco
# Processing Record 31 of Set 13 | balaipungut
# Processing Record 32 of Set 13 | vallenar
# Processing Record 33 of Set 13 | kulhudhuffushi
# Processing Record 34 of Set 13 | dharmavaram
# Processing Record 35 of Set 13 | severo-yeniseyskiy
# Processing Record 36 of Set 13 | bulgan
# Processing Record 37 of Set 13 | cairns
# Processing Record 38 of Set 13 | bahia blanca
# Processing Record 39 of Set 13 | brae
# Processing Record 40 of Set 13 | corinto
# Processing Record 41 of Set 13 | baculin
# Processing Record 42 of Set 13 | pedasi
# Processing Record 43 of Set 13 | cobija
# Processing Record 44 of Set 13 | san cristobal
# Processing Record 45 of Set 13 | buldana
# Processing Record 46 of Set 13 | port shepstone
# Processing Record 47 of Set 13 | quzhou
# Processing Record 48 of Set 13 | barcelos
# Processing Record 49 of Set 13 | chifeng
# Processing Record 50 of Set 13 | meru
# Processing Record 1 of Set 14 | macas
# Processing Record 2 of Set 14 | stokmarknes
# Processing Record 3 of Set 14 | znamenskoye
# Processing Record 4 of Set 14 | sucua
# Processing Record 5 of Set 14 | huilong
# Processing Record 6 of Set 14 | sand
# Processing Record 7 of Set 14 | linden
# Processing Record 8 of Set 14 | boa vista
# Processing Record 9 of Set 14 | porto novo
# Processing Record 10 of Set 14 | bokoro
# Processing Record 11 of Set 14 | tall kayf
# Processing Record 12 of Set 14 | kasra
# City not found. Skip
# Processing Record 13 of Set 14 | north bend
# Processing Record 14 of Set 14 | atsiki
# City not found. Skip
# Processing Record 15 of Set 14 | monte alegre de minas
# Processing Record 16 of Set 14 | birin
# Processing Record 17 of Set 14 | ammon
# Processing Record 18 of Set 14 | meybod
# Processing Record 19 of Set 14 | muscat
# Processing Record 20 of Set 14 | linxia
# Processing Record 21 of Set 14 | los llanos de aridane
# Processing Record 22 of Set 14 | indramayu
# Processing Record 23 of Set 14 | miles city
# Processing Record 24 of Set 14 | grivenskaya
# Processing Record 25 of Set 14 | gorno-chuyskiy
# City not found. Skip
# Processing Record 26 of Set 14 | leshukonskoye
# Processing Record 27 of Set 14 | domoni
# Processing Record 28 of Set 14 | lompoc
# Processing Record 29 of Set 14 | plymouth
# Processing Record 30 of Set 14 | mankapur
# Processing Record 31 of Set 14 | cardston
# Processing Record 32 of Set 14 | dubbo
# Processing Record 33 of Set 14 | matagami
# Processing Record 34 of Set 14 | kalengwa
# Processing Record 35 of Set 14 | baykalsk
# Processing Record 36 of Set 14 | boca do acre
# Processing Record 37 of Set 14 | gat
# Processing Record 38 of Set 14 | satitoa
# City not found. Skip
# Processing Record 39 of Set 14 | belmonte
# Processing Record 40 of Set 14 | el wasta
# City not found. Skip
# Processing Record 41 of Set 14 | kalmunai
# Processing Record 42 of Set 14 | zhangye
# Processing Record 43 of Set 14 | nerchinskiy zavod
# Processing Record 44 of Set 14 | igrim
# Processing Record 45 of Set 14 | heihe
# Processing Record 46 of Set 14 | chimore
# Processing Record 47 of Set 14 | san jeronimo
# Processing Record 48 of Set 14 | cananeia
# Processing Record 49 of Set 14 | ocos
# Processing Record 50 of Set 14 | sun city west
# Processing Record 1 of Set 15 | jarjis
# City not found. Skip
# Processing Record 2 of Set 15 | erdenet
# Processing Record 3 of Set 15 | vanimo
# Processing Record 4 of Set 15 | hokitika
# Processing Record 5 of Set 15 | porto santo
# Processing Record 6 of Set 15 | biltine
# Processing Record 7 of Set 15 | honningsvag
# Processing Record 8 of Set 15 | shima
# Processing Record 9 of Set 15 | louisbourg
# City not found. Skip
# Processing Record 10 of Set 15 | conde
# Processing Record 11 of Set 15 | havre-saint-pierre
# Processing Record 12 of Set 15 | mogadishu
# Processing Record 13 of Set 15 | karasjok
# Processing Record 14 of Set 15 | kuryk
# Processing Record 15 of Set 15 | mayor pablo lagerenza
# Processing Record 16 of Set 15 | burica
# City not found. Skip
# Processing Record 17 of Set 15 | puerto escondido
# Processing Record 18 of Set 15 | praya
# Processing Record 19 of Set 15 | abbeville
# Processing Record 20 of Set 15 | nichinan
# Processing Record 21 of Set 15 | virginia beach
# Processing Record 22 of Set 15 | inta
# Processing Record 23 of Set 15 | kozan
# Processing Record 24 of Set 15 | shagonar
# Processing Record 25 of Set 15 | dong hoi
# Processing Record 26 of Set 15 | santa marta
# Processing Record 27 of Set 15 | mimongo
# Processing Record 28 of Set 15 | tarakan
# Processing Record 29 of Set 15 | porto belo
# Processing Record 30 of Set 15 | ishigaki
# Processing Record 31 of Set 15 | le port
# Processing Record 32 of Set 15 | neiafu
# Processing Record 33 of Set 15 | balykshi
# Processing Record 34 of Set 15 | guerrero negro
# Processing Record 35 of Set 15 | bueno brandao
# Processing Record 36 of Set 15 | nemuro
# Processing Record 37 of Set 15 | kashi
# Processing Record 38 of Set 15 | shahapur
# Processing Record 39 of Set 15 | iracoubo
# Processing Record 40 of Set 15 | gabrovo
# Processing Record 41 of Set 15 | kingston
# Processing Record 42 of Set 15 | bonfim
# Processing Record 43 of Set 15 | matay
# Processing Record 44 of Set 15 | russell
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 683

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          albany      US  42.6001  -73.9662     73.72        76           6
# 1           bluff      NZ -46.6000  168.3333     41.81        73          99
# 2      champerico      GT  14.3000  -91.9167     82.35        84         100
# 3  port elizabeth      ZA -33.9180   25.5701     55.69        76           0
# 4         qandala      SO  11.4720   49.8728     87.87        53          22
# 5       esperance      AU -33.8667  121.9000     60.64        71           3
# 6      nikolskoye      RU  59.7035   30.7861     63.01        97          87
# 7            hilo      US  19.7297 -155.0900     79.25        84          49
# 8     pangnirtung      CA  66.1451  -65.7125     43.70        81         100
# 9           tiksi      RU  71.6872  128.8694     51.75        70          98
#
#    Wind Speed Current Description
# 0        5.28           clear sky
# 1       16.75     overcast clouds
# 2        6.33     overcast clouds
# 3        6.91           clear sky
# 4        3.42          few clouds
# 5       22.30           clear sky
# 6        5.26     overcast clouds
# 7        1.01    scattered clouds
# 8        4.94          light rain
# 9        4.12     overcast clouds

# %%
# Create the output file (CSV).
city_data_df.to_csv('WeatherPy_Database.csv')
city_data_df.to_csv("dframe.csv", sep=',')
